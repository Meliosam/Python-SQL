# %%
import pyodbc 


#Driver - Driver
#Server - Servidor
#DataBase - Nome do Banco de Dados

dadosConexao = ("Driver={SQLite3 ODBC Driver};Server=localhost;DataBase=Projeto_Compras.db")

#UID - Login 
#PWD - Senha 

conexao = pyodbc.connect(dadosConexao)
print("Conectado Com Sucesso!")

      
      
#cursor - Ferramenta para executar os comandos em SQL     
cursor = conexao.cursor()      


cursor.execute("Select *From Usuarios")
      
#passar os dados para a variavel
valores = cursor.fetchall()

print(valores)

#inserindo informaçoes #preparando os campos para  receber dados.
dados_usuario = ("Jose","987") 
#cursor para executar comandos SQL  "?" serve para novos dados, ou seja ainda não sabemos os dados                             
cursor.execute("INSERT INTO USUARIOS (Nome,Senha) Values (?,?)", dados_usuario)
conexao.commit()#Gravando no BD

#Selecionando a tabela do banco de dados
cursor.execute("Select *From Usuarios")
      
#passar os dados para a variavel
valores = cursor.fetchall()

print(valores)


#Fechar o cursor  e a conexao
cursor.close()
conexao.close()

# %%
import pyodbc 


#Driver - Driver
#Server - Servidor
#DataBase - Nome do Banco de Dados

dadosConexao = ("Driver={SQLite3 ODBC Driver};Server=localhost;DataBase=Projeto_Compras.db")

#UID - Login 
#PWD - Senha 

conexao = pyodbc.connect(dadosConexao)
print("Conectado Com Sucesso!")

      
      
#cursor - Ferramenta para executar os comandos em SQL     
cursor = conexao.cursor()      


cursor.execute("Select *From Usuarios")
      
#passar os dados para a variavel
valores = cursor.fetchall()

print(valores)

#inserindo informaçoes #preparando os campos para  receber dados.
dados_usuario = ("Jose","987") 
#cursor para executar comandos SQL  "?" serve para novos dados, ou seja ainda não sabemos os dados                             
cursor.execute("INSERT INTO USUARIOS (Nome,Senha) Values (?,?)", dados_usuario)
conexao.commit()#Gravando no BD

#Selecionando a tabela do banco de dados
cursor.execute("Select *From Usuarios")
      
#passar os dados para a variavel
valores = cursor.fetchall()

print(valores)


#Fechar o cursor  e a conexao
cursor.close()
conexao.close()
# Out:
# Conectado Com Sucesso!
# [(1, 'Gabriel Alves', '555'), (2, 'Bart', '888'), (3, 'Aluno', '666'), (4, 'Jose', '987'), (5, 'Jose', '987'), (6, 'Jose', '987'), (7, 'Jose', '987')]
# ---------------------------------------------------------------------------
# Error                                     Traceback (most recent call last)
# Cell In[1], line 32
#      30 dados_usuario = ("Jose","987")
#      31 #cursor para executar comandos SQL  "?" serve para novos dados, ou seja ainda não sabemos os dados
# ---> 32 cursor.execute("INSERT INTO USUARIOS (Nome,Senha) Values (?,?)", dados_usuario)
#      33 conexao.commit()#Gravando no BD
#      35 #Selecionando a tabela do banco de dados
#
# Error: ('HY000', '[HY000] database is locked (5) (5) (SQLExecDirectW)')

# %%
#importa o modulo pyodbc para conexão com bancos de dados
import pyodbc

#importa o modulo tkinter para construção de interfaces graficas 
from tkinter import *

#importa a classe ttk do  modulo tkinter
from tkinter import ttk 

#Criando a janela principal para a tela de login
janela_principal= Tk()
janela_principal.title("Tela de Login")

#bg - background (cor do fundo)
#Definindo a cor de fundo da janela 
janela_principal.configure(bg="#F5F5F5")

#fg- foreground (cor da letra)
#row - linha
#column coluna
#columnspan - quantas colunas vai ocupar no grid 
#grid e tipo uma tabela, aonde é dividido em colunas e em pedaços, então conseguimos colocar esses campos nos pedaços que o grid separa 


titulo_lbl = Label(janela_principal, text="Tela de Login", font="Arial 20", fg="blue", bg="#F5F5F5")
titulo_lbl.grid(row=0, column=0, columnspan=2, pady=20)
    

#inicia a janela tkinter
janela_principal.mainloop()
